# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 2, np.nan])
s
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
print(s[0], s.sum())
# Out:
# 1.0 3.0

# %%
df = pd.DataFrame({'A': [1,2], 'B':[3, 4]}) # 더 자주 쓰임
df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(6, 4))
df
# Out:
#           0         1         2         3
# 0 -0.484125  0.852468  1.012655 -0.108730
# 1  0.873793  0.847406 -0.142804 -0.347826
# 2  1.094474  1.829422  0.240129  0.706518
# 3 -0.255792  0.152747  0.359632  0.031557
# 4 -1.255641 -0.804387  0.530812 -0.138984
# 5  0.191684 -0.845189  1.032111 -0.878966

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20220303', periods=6))
df
# Out:
#                    0         1         2         3
# 2022-03-03  1.695614  0.551608 -0.563695 -0.281995
# 2022-03-04  0.674628 -0.765844 -0.232129 -1.198730
# 2022-03-05 -0.278594 -0.476359  1.490566 -0.561803
# 2022-03-06  0.679693 -0.990447 -2.061118 -1.284050
# 2022-03-07  0.592015  0.599809 -0.858053  0.636544
# 2022-03-08  1.210822  0.740325 -1.120019  1.966391

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20220303', periods=6), columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240
# 2022-03-04 -0.151608 -1.771478  0.286691 -0.512503
# 2022-03-05 -1.454965 -1.692072  0.376181 -0.903927
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211
# 2022-03-07  1.165055  0.284112  0.271331  0.079629
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614

# %%
df.head(1)
# Out:
#                    A         B         C        D
# 2022-03-03  0.189646 -0.665437 -0.881725  0.14724

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211
# 2022-03-07  1.165055  0.284112  0.271331  0.079629
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614

# %%
df.index
# Out:
# DatetimeIndex(['2022-03-03', '2022-03-04', '2022-03-05', '2022-03-06',
#                '2022-03-07', '2022-03-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.18964633, -0.66543732, -0.8817246 ,  0.14723953],
#        [-0.15160757, -1.77147842,  0.28669075, -0.51250338],
#        [-1.45496526, -1.6920724 ,  0.37618095, -0.90392741],
#        [-0.06710831,  0.79166441,  1.1288448 ,  1.70721091],
#        [ 1.16505516,  0.28411212,  0.27133129,  0.07962905],
#        [ 0.42918873,  1.43666985,  1.17090838, -2.21061428]])

# %%
df.describe() # table의 값을 각 수치별로 모아서 보여줌.
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.018368 -0.269424  0.392039 -0.282161
# std    0.862544  1.325141  0.748053  1.298573
# min   -1.454965 -1.771478 -0.881725 -2.210614
# 25%   -0.130483 -1.435414  0.275171 -0.806071
# 50%    0.061269 -0.190663  0.331436 -0.216437
# 75%    0.369303  0.664776  0.940679  0.130337
# max    1.165055  1.436670  1.170908  1.707211

# %%
df.T # 행, 열 전치
# Out:
#    2022-03-03  2022-03-04  2022-03-05  2022-03-06  2022-03-07  2022-03-08
# A    0.189646   -0.151608   -1.454965   -0.067108    1.165055    0.429189
# B   -0.665437   -1.771478   -1.692072    0.791664    0.284112    1.436670
# C   -0.881725    0.286691    0.376181    1.128845    0.271331    1.170908
# D    0.147240   -0.512503   -0.903927    1.707211    0.079629   -2.210614

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2022-03-04 -0.151608 -1.771478  0.286691 -0.512503
# 2022-03-05 -1.454965 -1.692072  0.376181 -0.903927
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240
# 2022-03-07  1.165055  0.284112  0.271331  0.079629
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240
# 2022-03-04 -0.151608 -1.771478  0.286691 -0.512503
# 2022-03-05 -1.454965 -1.692072  0.376181 -0.903927

# %%
df['20220304':'20220307']
# Out:
#                    A         B         C         D
# 2022-03-04 -0.151608 -1.771478  0.286691 -0.512503
# 2022-03-05 -1.454965 -1.692072  0.376181 -0.903927
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211
# 2022-03-07  1.165055  0.284112  0.271331  0.079629

# %%
df.loc['20220308']
# Out:
# A    0.429189
# B    1.436670
# C    1.170908
# D   -2.210614
# Name: 2022-03-08 00:00:00, dtype: float64

# %%
df.loc["20220304", ['A', 'B']]
# Out:
# A   -0.151608
# B   -1.771478
# Name: 2022-03-04 00:00:00, dtype: float64

# %%
df.loc["20220304":"20220306", ['A', 'B']]
# Out:
#                    A         B
# 2022-03-04 -0.151608 -1.771478
# 2022-03-05 -1.454965 -1.692072
# 2022-03-06 -0.067108  0.791664

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2022-03-03  0.189646 -0.665437
# 2022-03-04 -0.151608 -1.771478
# 2022-03-05 -1.454965 -1.692072
# 2022-03-06 -0.067108  0.791664
# 2022-03-07  1.165055  0.284112
# 2022-03-08  0.429189  1.436670

# %%
df.iloc[0, 0]
# Out:
# 0.18964633153756266

# %%
df.iloc[0:2, 0:2]
# Out:
#                    A         B
# 2022-03-03  0.189646 -0.665437
# 2022-03-04 -0.151608 -1.771478

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240
# 2022-03-07  1.165055  0.284112  0.271331  0.079629
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614

# %%
df[df.B > 0]
# Out:
#                    A         B         C         D
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211
# 2022-03-07  1.165055  0.284112  0.271331  0.079629
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-03-03  0.189646       NaN       NaN  0.147240
# 2022-03-04       NaN       NaN  0.286691       NaN
# 2022-03-05       NaN       NaN  0.376181       NaN
# 2022-03-06       NaN  0.791664  1.128845  1.707211
# 2022-03-07  1.165055  0.284112  0.271331  0.079629
# 2022-03-08  0.429189  1.436670  1.170908       NaN

# %%
df
# Out:
#                    A         B         C         D
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240
# 2022-03-04 -0.151608 -1.771478  0.286691 -0.512503
# 2022-03-05 -1.454965 -1.692072  0.376181 -0.903927
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211
# 2022-03-07  1.165055  0.284112  0.271331  0.079629
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614

# %%
df2 = df.copy()
df2['E'] = ['one', 'two', 'three', 'four', 'five', 'six']
df2
# Out:
#                    A         B         C         D      E
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240    one
# 2022-03-04 -0.151608 -1.771478  0.286691 -0.512503    two
# 2022-03-05 -1.454965 -1.692072  0.376181 -0.903927  three
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211   four
# 2022-03-07  1.165055  0.284112  0.271331  0.079629   five
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614    six

# %%
df2[df2['E'].isin(['one', 'four'])]
# Out:
#                    A         B         C         D     E
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240   one
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211  four

# %%
s = pd.Series([1, 2, 3, 4, 5, 6], index = pd.date_range('20220303', periods = 6))
s
# Out:
# 2022-03-03    1
# 2022-03-04    2
# 2022-03-05    3
# 2022-03-06    4
# 2022-03-07    5
# 2022-03-08    6
# Freq: D, dtype: int64

# %%
df['E'] = s

# %%
df
# Out:
#                    A         B         C         D  E
# 2022-03-03  0.189646 -0.665437 -0.881725  0.147240  1
# 2022-03-04 -0.151608 -1.771478  0.286691 -0.512503  2
# 2022-03-05 -1.454965 -1.692072  0.376181 -0.903927  3
# 2022-03-06 -0.067108  0.791664  1.128845  1.707211  4
# 2022-03-07  1.165055  0.284112  0.271331  0.079629  5
# 2022-03-08  0.429189  1.436670  1.170908 -2.210614  6

# %%
df.shift(1) # 모든 값 내리기
# Out:
#                    A         B         C         D    E
# 2022-03-03       NaN       NaN       NaN       NaN  NaN
# 2022-03-04  0.189646 -0.665437 -0.881725  0.147240  1.0
# 2022-03-05 -0.151608 -1.771478  0.286691 -0.512503  2.0
# 2022-03-06 -1.454965 -1.692072  0.376181 -0.903927  3.0
# 2022-03-07 -0.067108  0.791664  1.128845  1.707211  4.0
# 2022-03-08  1.165055  0.284112  0.271331  0.079629  5.0

# %%
df = pd.DataFrame(np.random.randn(2, 2))
df
# Out:
#           0         1
# 0 -0.486327 -0.653949
# 1 -0.796625  0.452461

# %%
pd.concat([df, df]) # 붙이기
# Out:
#           0         1
# 0 -0.486327 -0.653949
# 1 -0.796625  0.452461
# 0 -0.486327 -0.653949
# 1 -0.796625  0.452461

# %%
df = pd.DataFrame(np.random.rand(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.454826  0.129891  0.860955  0.101934
# 1  0.422542  0.766173  0.792028  0.095332
# 2  0.890231  0.911516  0.148385  0.466792
# 3  0.365147  0.101369  0.256429  0.238879
# 4  0.900288  0.262204  0.444412  0.188859
# 5  0.754390  0.085003  0.058132  0.926841
# 6  0.924973  0.811435  0.766176  0.494185
# 7  0.327903  0.775709  0.850276  0.389092

# %%
s = df.iloc[0]
s
# Out:
# A    0.454826
# B    0.129891
# C    0.860955
# D    0.101934
# Name: 0, dtype: float64

# %%
df.append(s)
# Out:
#           A         B         C         D
# 0  0.454826  0.129891  0.860955  0.101934
# 1  0.422542  0.766173  0.792028  0.095332
# 2  0.890231  0.911516  0.148385  0.466792
# 3  0.365147  0.101369  0.256429  0.238879
# 4  0.900288  0.262204  0.444412  0.188859
# 5  0.754390  0.085003  0.058132  0.926841
# 6  0.924973  0.811435  0.766176  0.494185
# 7  0.327903  0.775709  0.850276  0.389092
# 0  0.454826  0.129891  0.860955  0.101934

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.454826  0.129891  0.860955  0.101934
# 1  0.422542  0.766173  0.792028  0.095332
# 2  0.890231  0.911516  0.148385  0.466792
# 3  0.365147  0.101369  0.256429  0.238879
# 4  0.900288  0.262204  0.444412  0.188859
# 5  0.754390  0.085003  0.058132  0.926841
# 6  0.924973  0.811435  0.766176  0.494185
# 7  0.327903  0.775709  0.850276  0.389092
# 8  0.454826  0.129891  0.860955  0.101934

# %%
df = pd.DataFrame({'A':['foo', 'bar', 'foo', 'bar'], 'B':np.random.randn(4)})
df
# Out:
#      A         B
# 0  foo  0.149447
# 1  bar  1.504742
# 2  foo  0.204043
# 3  bar -2.227843

# %%
df.groupby('A').sum()
# Out:
#             B
# A
# bar -0.723102
# foo  0.353490

# %%
import pandas_datareader

# %%
df = pandas_datareader.data.DataReader('AAPL', 'yahoo', '2014-01-01')

# %%
df.head(2)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2013-12-31  20.045713  19.785713  19.791786  20.036428  223084400.0  17.743864
# 2014-01-02  19.893929  19.715000  19.845715  19.754642  234684800.0  17.494316
